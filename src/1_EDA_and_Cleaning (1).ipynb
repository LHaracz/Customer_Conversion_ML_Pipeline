# %% [markdown]
# Compared to the raw dataset, we lost 149 rows (1.86% of data), primarily due to values of 0 in WebsiteVisits, as a value of 0 would mean the customer did not visit the site at all. No significant change in distributions was observed.

# %% [markdown]
# ### Loading in the dataset
# ---

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/MISY331/digital_marketing_campaign_dataset.csv")
df.shape
# Out:
# (8000, 20)

# %%
df.head()
# Out:
#    CustomerID  Age  Gender  Income CampaignChannel CampaignType      AdSpend  \
# 0        8000   56  Female  136912    Social Media    Awareness  6497.870068
# 1        8001   69    Male   41760           Email    Retention  3898.668606
# 2        8002   46  Female   88456             PPC    Awareness  1546.429596
# 3        8003   32  Female   44085             PPC   Conversion   539.525936
# 4        8004   60  Female   83964             PPC   Conversion  1678.043573
#
#    ClickThroughRate  ConversionRate  WebsiteVisits  PagesPerVisit  TimeOnSite  \
# 0          0.043919        0.088031              0       2.399017    7.396803
# 1          0.155725        0.182725             42       2.917138    5.352549
# 2          0.277490        0.076423              2       8.223619   13.794901
# 3          0.137611        0.088004             47       4.540939   14.688363
# 4          0.252851        0.109940              0       2.046847   13.993370
#
#    SocialShares  EmailOpens  EmailClicks  PreviousPurchases  LoyaltyPoints  \
# 0            19           6            9                  4            688
# 1             5           2            7                  2           3459
# 2             0          11            2                  8           2337
# 3            89           2            2                  0           2463
# 4             6           6            6                  8           4345
#
#   AdvertisingPlatform AdvertisingTool  Conversion
# 0            IsConfid      ToolConfid           1
# 1            IsConfid      ToolConfid           1
# 2            IsConfid      ToolConfid           1
# 3            IsConfid      ToolConfid           1
# 4            IsConfid      ToolConfid           1

# %% [markdown]
# ### Checking for missing values

# %%
df.isnull().sum()
# Out:
# CustomerID             0
# Age                    0
# Gender                 0
# Income                 0
# CampaignChannel        0
# CampaignType           0
# AdSpend                0
# ClickThroughRate       0
# ConversionRate         0
# WebsiteVisits          0
# PagesPerVisit          0
# TimeOnSite             0
# SocialShares           0
# EmailOpens             0
# EmailClicks            0
# PreviousPurchases      0
# LoyaltyPoints          0
# AdvertisingPlatform    0
# AdvertisingTool        0
# Conversion             0
# dtype: int64

# %% [markdown]
# ### Removing Duplicates

# %%
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (8000, 20)

# %% [markdown]
# Droping all rows where WebsiteVisits = 0, Rows Lost: 149

# %%
df.drop(df[df['WebsiteVisits'] == 0].index, inplace=True)
df.shape
# Out:
# (7851, 20)

# %% [markdown]
# Create Dummy Variables

# %%
## Dummy Columns
dummy_cols = ['Gender', 'CampaignChannel', 'CampaignType']
df = pd.get_dummies(df,
                    columns = dummy_cols,
                    prefix= ['is ', 'channel ', 'type '], drop_first = True, dtype = int)
df.head()
# Out:
#    CustomerID  Age  Income      AdSpend  ClickThroughRate  ConversionRate  \
# 1        8001   69   41760  3898.668606          0.155725        0.182725
# 2        8002   46   88456  1546.429596          0.277490        0.076423
# 3        8003   32   44085   539.525936          0.137611        0.088004
# 5        8005   25   42925  9579.388247          0.153795        0.161316
# 6        8006   38   25615  7302.899852          0.040975        0.060977
#
#    WebsiteVisits  PagesPerVisit  TimeOnSite  SocialShares  ...  \
# 1             42       2.917138    5.352549             5  ...
# 2              2       8.223619   13.794901             0  ...
# 3             47       4.540939   14.688363            89  ...
# 5              6       2.125850    7.752831            95  ...
# 6             42       1.753995   10.698672            54  ...
#
#    AdvertisingTool  Conversion  is _Male  channel _PPC channel _Referral  \
# 1       ToolConfid           1         1             0                 0
# 2       ToolConfid           1         0             1                 0
# 3       ToolConfid           1         0             1                 0
# 5       ToolConfid           1         0             0                 0
# 6       ToolConfid           1         0             0                 1
#
#   channel _SEO  channel _Social Media  type _Consideration  type _Conversion  \
# 1            0                      0                    0                 0
# 2            0                      0                    0                 0
# 3            0                      0                    0                 1
# 5            0                      1                    0                 0
# 6            0                      0                    0                 0
#
#    type _Retention
# 1                1
# 2                0
# 3                0
# 5                0
# 6                0
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Dropping irrelevant columns

# %%
columns_to_exclude = ['AdvertisingPlatform', 'AdvertisingTool']

df=df.drop(columns = columns_to_exclude)

# %%
df.head()
# Out:
#    CustomerID  Age  Income      AdSpend  ClickThroughRate  ConversionRate  \
# 1        8001   69   41760  3898.668606          0.155725        0.182725
# 2        8002   46   88456  1546.429596          0.277490        0.076423
# 3        8003   32   44085   539.525936          0.137611        0.088004
# 5        8005   25   42925  9579.388247          0.153795        0.161316
# 6        8006   38   25615  7302.899852          0.040975        0.060977
#
#    WebsiteVisits  PagesPerVisit  TimeOnSite  SocialShares  ...  LoyaltyPoints  \
# 1             42       2.917138    5.352549             5  ...           3459
# 2              2       8.223619   13.794901             0  ...           2337
# 3             47       4.540939   14.688363            89  ...           2463
# 5              6       2.125850    7.752831            95  ...           3316
# 6             42       1.753995   10.698672            54  ...            930
#
#    Conversion  is _Male  channel _PPC  channel _Referral  channel _SEO  \
# 1           1         1             0                  0             0
# 2           1         0             1                  0             0
# 3           1         0             1                  0             0
# 5           1         0             0                  0             0
# 6           1         0             0                  1             0
#
#    channel _Social Media  type _Consideration  type _Conversion  \
# 1                      0                    0                 0
# 2                      0                    0                 0
# 3                      0                    0                 1
# 5                      1                    0                 0
# 6                      0                    0                 0
#
#    type _Retention
# 1                1
# 2                0
# 3                0
# 5                0
# 6                0
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Exporting train and test set, and saving the cleaned csv

# %%
import pickle
from sklearn.model_selection import train_test_split
X = df.drop(columns=['Conversion', 'CustomerID'])  # Drop target & ID
y = df['Conversion']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)
# Save the train/test splits to pickle files
with open('/content/drive/MyDrive/Colab Notebooks/MISY331/X_train.p', 'wb') as f:
    pickle.dump(X_train, f)

with open('/content/drive/MyDrive/Colab Notebooks/MISY331/X_test.p', 'wb') as f:
    pickle.dump(X_test, f)

with open('/content/drive/MyDrive/Colab Notebooks/MISY331/y_train.p', 'wb') as f:
    pickle.dump(y_train, f)

with open('/content/drive/MyDrive/Colab Notebooks/MISY331/y_test.p', 'wb') as f:
    pickle.dump(y_test, f)

# %%
df.to_csv('digital_marketing_campaign_dataset_cleaned.csv', index=False)
